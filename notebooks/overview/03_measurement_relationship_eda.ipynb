# %% [markdown]
# # Measurement 관계 EDA
#
# `reduced_measurement_1h`를 일 단위로 집계해 전기·열·기상 measurement의 상관 구조와 물리적으로 설명 가능한 관계를 확인한다.
#
# 산출물 위치:
#
# - `outputs/tables/measurement_relationship_eda/`
# - `outputs/figures/measurement_relationship_eda/`
#
# 주의:
#
# - PV `P`는 발전 방향이 음수로 표현되는 구간이 있어 일사량과 음의 상관으로 해석한다.
# - 냉방·난방과 외기온 관계는 계절 효과가 섞여 있으므로 단순 상관만으로 feature 후보를 확정하지 않는다.

# %%
from pathlib import Path
import pandas as pd
BASE = Path('../../outputs/tables/measurement_relationship_eda')
key = pd.read_csv(BASE / 'measurement_key_relationships.csv')
top = pd.read_csv(BASE / 'reduced_1h_top_correlation_pairs.csv')
display(key)
display(top.head(20))
