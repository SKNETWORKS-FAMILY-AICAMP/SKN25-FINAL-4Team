# %% [markdown]
# # Quality lineage EDA
#
# raw table이 비어 있는 현재 DB 상태를 명시하고, source file load counter와 CR coverage 기준으로 품질 계보를 점검한다.

# %%
from pathlib import Path
import pandas as pd
BASE = Path('../../outputs/tables/quality_lineage_eda')
summary = pd.read_csv(BASE / 'load_balance_status_summary.csv')
summary
