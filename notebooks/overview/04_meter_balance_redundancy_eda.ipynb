# %% [markdown]
# # 계량기 balance/redundancy EDA
#
# `계량기_메타데이터.md`의 equipment group과 redundancy pair 기준을 로컬 분석에 적용해 계량기 간 일관성을 확인한다. DB schema에는 쓰지 않는다.

# %%
from pathlib import Path
import pandas as pd
BASE = Path('../../outputs/tables/meter_balance_redundancy_eda')
red = pd.read_csv(BASE / 'redundancy_pair_p_comparison.csv')
red.sort_values('corr')
